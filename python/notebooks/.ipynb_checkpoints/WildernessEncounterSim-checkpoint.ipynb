# %%
import pandas as pd
import numpy as np
import random
import re
from tqdm import tqdm

# %%
NUM_ENCOUNTERS = 1000;
MONSTER_NUM_COL = 1;
MONSTER_HDN_COL = 12;
MONSTER_EHD_COL = 13

# %%
mainTable = pd.read_csv('../../WildMainTable.csv')
mainTable
# Out:
#    Die   Clear   Woods    River    Swamp Mountain  Desert    City
# 0    1     Men     Men      Men      Men      Men     Men     Men
# 1    2   Flyer   Flyer    Flyer    Flyer    Flyer   Flyer  Undead
# 2    3   Giant   Giant    Giant    Giant    Giant   Giant  Undead
# 3    4   Lycan   Lycan    Lycan    Lycan    Lycan     Men     Men
# 4    5  Animal   Lycan  Swimmer  Swimmer   Animal  Animal       -
# 5    6     Men     Men  Swimmer   Undead    Giant  Dragon       -
# 6    7  Animal  Animal   Animal   Undead   Dragon       -       -
# 7    8  Dragon  Dragon   Dragon   Dragon   Dragon       -       -

# %%
subTable = pd.read_csv('../../WildSubTable.csv')
subTable
# Out:
#     Die       Men Typical      Men Mountain Men Desert  Men Water       Flyer  \
# 0     1            Bandit            Bandit      Nomad  Buccaneer     Pegasus
# 1     2           Brigand         Berserker    Dervish     Pirate         Roc
# 2     3       Necromancer           Brigand      Nomad  Buccaneer     Chimera
# 3     4            Wizard              Lord       Lord     Pirate  Hippogriff
# 4     5            Bandit            Wizard     Wizard  Buccaneer     Griffon
# 5     6         Berserker         Superhero      Nomad     Merman   Manticore
# 6     7              Lord           Caveman          -          -         Roc
# 7     8         Superhero       Necromancer          -          -      Wyvern
# 8     9           Brigand  Evil High Priest          -          -      Dragon
# 9    10            Bandit           Caveman          -          -     Pegasus
# 10   11  Evil High Priest         Patriarch          -          -  Hippogriff
# 11   12         Patriarch         Berserker          -          -      Balrog
#
#       Undead      Giant      Lycan        Swimmer         Dragon  \
# 0   Skeleton     Kobold   Werewolf     Giant Crab  Dragon, Black
# 1     Zombie     Goblin   Wereboar          Nixie  Dragon, White
# 2      Ghoul        Orc  Weretiger  Giant Octopus  Dragon, Green
# 3      Wight  Hobgoblin   Werebear    Giant Squid   Dragon, Blue
# 4     Wraith      Gnoll          -    Sea Monster    Dragon, Red
# 5      Mummy       Ogre          -    Giant Snake   Dragon, Gold
# 6    Spectre      Troll          -      Crocodile     Cockatrice
# 7    Vampire      Giant          -    Giant Leech       Basilisk
# 8          -      Gnome          -         Merman         Wyvern
# 9          -      Dwarf          -          Nixie         Balrog
# 10         -        Elf          -     Giant Fish        Chimera
# 11         -     Treant          -  Dragon Turtle          Hydra
#
#              Animal
# 0      Large Spider
# 1   Giant Centipede
# 2      Giant Lizard
# 3        Giant Toad
# 4         Giant Ant
# 5      Giant Weasel
# 6         White Ape
# 7      Giant Beetle
# 8    Giant Scorpion
# 9              Lion
# 10             Boar
# 11      Giant Snake

# %%
monsterTable = pd.read_csv('../../MonsterDatabase.csv')
monsterTable
# Out:
#                      Monster Number  AC  MV   HD Lair% Treas  Atk  Dam  \
# 0                        Rat  1d100   7  15  1/6     -     -    1    1
# 1            Giant Centipede   2d12   9  15  1/3     -     -    1    0
# 2                  Giant Rat   5d10   7  12  1/2    10     C    1  1d3
# 3                     Jackal    1d6   8  12  1/2     -     -    1  1d3
# 4         Giant Beetle, Fire    3d4   4   9  1-1     -     -    1  1d6
# ..                       ...    ...  ..  ..  ...   ...   ...  ...  ...
# 178              Will-O-Wisp      1  -8  18    9     1     A    1  2d6
# 179  Earth Elemental, Medium      1   2   6   12     -     -    1  3d6
# 180    Fire Elemental, Large      1   2  12   16     -     -    1  2d6
# 181   Water Elemental, Large      1   2   6   16     -     -    1  2d6
# 182   Earth Elemental, Large      1   2   6   16     -     -    1  3d6
#
#                            Special Type Align   HD# EHD Env  Source
# 0                                -    A     N   0.2   0   D      M2
# 1                      Poison (-4)    A     N   0.3   1   D      M1
# 2                          Disease    A     N   0.5   1   D  S1, M1
# 3                                -    A     N   0.5   1   W  S1, M1
# 4                            Light    A     N   0.8   1   D      S2
# ..                             ...  ...   ...   ...  ..  ..     ...
# 178            Light, Invisibility    X     N   9.0  27   D      S1
# 179                 MagicToHit (2)    X     N  12.0  33   S   O, S1
# 180                 MagicToHit (2)    X     N  16.0  33   S   O, S1
# 181  Swimming (18), MagicToHit (2)    X     N  16.0  33   S   O, S1
# 182                 MagicToHit (2)    X     N  16.0  40   S   O, S1
#
# [183 rows x 16 columns]

# %%
terrainlist = mainTable.columns[1:].tolist()
terrainlist
# Out:
# ['Clear', 'Woods', 'River', 'Swamp', 'Mountain', 'Desert', 'City']

# %%
# Get terrain and terrain index
random_index = random.randrange(len(terrainlist))
terrain = terrainlist[random_index]
terrainIndex = random_index + 1
terrain
# Out:
# 'Swamp'

# %%
def monsterFixup(monName):
    #find giant subtype
    #print("startofFixup", monName)
    if monName == "Giant":
        d10 = random.randint(1,10)
        if d10 <= 6:
            monName = "Giant, Hill"
            return monName
        if d10 == 7:
            monName = "Giant, Stone"
            return monName
        if d10 == 8:
            monName = "Giant, Frost"
            return monName
        if d10 == 9:
            monName = "Giant, Fire";
            return monName
        if d10 == 10:
            monName = "Giant, Cloud"
            return monName

    # Find dragon subtype
    if monName == "Dragon":
        d6 = random.randint(1,6)
        if d6 == 1:
            monName = "Dragon, White"
            return monName
        if d6 == 2:
            monName = "Dragon, Black"
            return monName
        if d6 == 3:
            monName = "Dragon, Green";
            return monName
        if d6 == 4:
            monName = "Dragon, Blue"
            return monName
        if d6 == 5:
            monName = "Dragon, Red"
            return monName
        if d6 == 6:
            monName = "Dragon, Gold"
            return monName
    
    # Find specific giant animal
    if monName == "Giant Snake":
        monName = "Giant Snake, Constrictor"
        return monName
    if monName == "Giant Beetle":
        monName = "Giant Beetle, Bombardier"
        return monName
    if monName == "Giant Ant":
        monName = "Giant Ant, Worker"
        return monName
    if monName == "Sea Monster":
        monName = "Sea Monster, Small"
        return monName
    if monName == "Hydra":
        monName = "Hydra, 10 Heads"
        return monName
    if monName == "Roc":
        monName = "Roc, Small"	        
        return monName
    #print("endofFixup", monName)

    return monName

def getNPCEntourage():
    sumEnt = 0
    numEnt = random.randint(1,6) + random.randint(1,6)
    for i in range(numEnt):
        sumEnt += random.randint(1,4)
        #print(sumEnt)
    return sumEnt

def EHDFixup(monName, EHD):
    #Fill in null EHDs with estimated value.
    if EHD == 0:
        if monName == "Dragon, Gold":
            return 40
    return EHD
    
def handleNPCType(monsterName):
    NPClevel = 0
    if monsterName == "Wizard":
        NPClevel = 11
    if monsterName == "Necromancer":
        NPClevel = 10
    if monsterName == "Lord":
        NPClevel = 9
    if monsterName == "Superhero" or monsterName == "Patriarch" or monsterName == "Evil High Priest":
        NPClevel = 8
    if NPClevel == 0:
        return NPClevel
    else:
        return NPClevel + getNPCEntourage()
       
    
def rollEncounterByMonster(monsterName):
    # Special handling for NPC types
    NPCValue = handleNPCType(monsterName)
    #print("NPCValue", NPCValue)
    if NPCValue > 0:
        return NPCValue
    
    #Find index in monster table
    monsterDice = monsterTable.loc[monsterTable["Monster"] == monsterName]["Number"].values[0]
    #print(monsterDice)
    addition = 0
    multiplier = 1
    # RegEx code from @user1803551 on StackExchange:
    # http://stackoverflow.com/questions/35020687/
    # how-to-parse-dice-notation-with-a-java-regular-expression
    pattern = re.compile("([1-9]\\d*)?d([1-9]\\d*)([/x][1-9]\\d*)?([+-]\\d+)?")
    m = pattern.search(monsterDice)
    if m:
        #print("m.groups", m.groups())
        dice = int(m.groups()[0])
        #print("dice", dice)
        if m.groups()[1] is not None:
            sides = int(m.groups()[1])
            #print("sides", sides)
        if m.groups()[2] is not None:
            multiplier = int(m.groups()[2].replace('x',''))
            #print("multiplier", multiplier)
        if m.groups()[3] is not None:
            addition = int(m.groups()[3])
            #print("addition", addition)
            
        monsterNumber = sum(random.randint(1,sides) for _ in range(dice))
        #print(monsterNumber)
        monsterNumber = monsterNumber + addition
        #print(monsterNumber)
        monsterNumber = monsterNumber * multiplier
        #print(monsterNumber)
    else:
        monsterNumber = 1
        
    try:
        EHD = int(monsterTable.loc[monsterTable["Monster"] == monsterName]["EHD"].values[0])
    except Exception as EHDError:
        EHD = 0
    #print("EHDlookup", EHD)
    EHD = EHDFixup(monsterName, EHD)
    #print("EHDfixup", EHD)
    
    totalEHD = monsterNumber * EHD
    #print("totalEHD", totalEHD)
    hitDiceNum = monsterTable.loc[monsterTable["Monster"] == monsterName]["HD#"].values[0].astype('float32')
    #print("hitDiceNum", hitDiceNum)
    if hitDiceNum <= 1.0:
        totalEHD = totalEHD / 4.0
        
    #print("returntotalEHD", totalEHD)
    return totalEHD
        

def rollEncounterByTerrain():
    dice_type = (~mainTable[terrain].str.contains('-')).sum()
    subTableName = mainTable[terrain][0:dice_type].sample().values[0]
    subTableName == "Men"
    
    if subTableName == "Men":
        subTableName = "Men Typical"
    if terrain == "Mountain":
        subTableName = "Men Mountain"
    if terrain == "Desert":
        subTableName = "Men Desert"
    if terrain == "Water":
        subTableName = "Men Water"
    
    monster_dice_type = (~subTable[subTableName].str.contains('-')).sum()
    monsterName = subTable[subTableName][0:monster_dice_type].sample().values[0]
    #print("monsterName", monsterName)
    monsterName = monsterFixup(monsterName)
    #print("monsterNamefixup", monsterName)
    print("subTable:", subTableName, "Monster:", monsterName)
    
    ehd = rollEncounterByMonster(monsterName)
    return [monsterName, ehd, subTableName]

# %%
testrun = 10
encounter_dict = {}
encounter_dict['Monster'] = []
encounter_dict['EHD'] = []
encounter_dict['subTable'] = []
for encounter in range(NUM_ENCOUNTERS):
#for encounter in range(testrun):    
    monster, ehd, subtable = rollEncounterByTerrain()
    encounter_dict['Monster'].append(monster)
    encounter_dict['EHD'].append(ehd)
    encounter_dict['subTable'].append(subtable)
# Out:
# subTable: Flyer Monster: Wyvern
# subTable: Swimmer Monster: Merman
# subTable: Undead Monster: Wraith
# subTable: Lycan Monster: Werewolf
# subTable: Lycan Monster: Werewolf
# subTable: Flyer Monster: Roc, Small
# subTable: Undead Monster: Wraith
# subTable: Undead Monster: Wraith
# subTable: Giant Monster: Orc
# subTable: Lycan Monster: Werewolf
# subTable: Flyer Monster: Balrog
# subTable: Dragon Monster: Balrog
# subTable: Lycan Monster: Werebear
# subTable: Undead Monster: Mummy
# subTable: Giant Monster: Dwarf
# subTable: Men Typical Monster: Superhero
# subTable: Undead Monster: Vampire
# subTable: Dragon Monster: Hydra, 10 Heads
# subTable: Flyer Monster: Roc, Small
# subTable: Undead Monster: Vampire
# subTable: Men Typical Monster: Bandit
# subTable: Swimmer Monster: Nixie
# subTable: Lycan Monster: Werebear
# subTable: Flyer Monster: Roc, Small
# subTable: Lycan Monster: Wereboar
# subTable: Swimmer Monster: Merman
# subTable: Flyer Monster: Chimera
# subTable: Dragon Monster: Dragon, Black
# subTable: Swimmer Monster: Giant Crab
# subTable: Lycan Monster: Weretiger
# subTable: Flyer Monster: Hippogriff
# subTable: Undead Monster: Wight
# subTable: Undead Monster: Wraith
# subTable: Men Typical Monster: Berserker
# subTable: Lycan Monster: Weretiger
# subTable: Undead Monster: Ghoul
# subTable: Undead Monster: Wight
# subTable: Giant Monster: Ogre
# subTable: Dragon Monster: Dragon, White
# subTable: Men Typical Monster: Bandit
# subTable: Men Typical Monster: Bandit
# subTable: Men Typical Monster: Bandit
# subTable: Undead Monster: Zombie
# subTable: Men Typical Monster: Bandit
# subTable: Swimmer Monster: Dragon Turtle
# subTable: Undead Monster: Ghoul
# subTable: Flyer Monster: Griffon
# subTable: Lycan Monster: Werebear
# subTable: Lycan Monster: Weretiger
# subTable: Dragon Monster: Hydra, 10 Heads
# subTable: Dragon Monster: Dragon, Green
# subTable: Flyer Monster: Balrog
# subTable: Undead Monster: Mummy
# subTable: Giant Monster: Elf
# subTable: Men Typical Monster: Bandit
# subTable: Lycan Monster: Wereboar
# subTable: Dragon Monster: Chimera
# subTable: Lycan Monster: Wereboar
# subTable: Giant Monster: Gnoll
# subTable: Undead Monster: Wraith
# subTable: Giant Monster: Goblin
# subTable: Undead Monster: Ghoul
# subTable: Undead Monster: Vampire
# subTable: Undead Monster: Vampire
# subTable: Giant Monster: Gnome
# subTable: Dragon Monster: Basilisk
# subTable: Lycan Monster: Weretiger
# subTable: Lycan Monster: Werewolf
# subTable: Dragon Monster: Chimera
# subTable: Flyer Monster: Dragon, Green
# subTable: Lycan Monster: Werewolf
# subTable: Lycan Monster: Werewolf
# subTable: Swimmer Monster: Giant Leech
# subTable: Swimmer Monster: Merman
# subTable: Lycan Monster: Werewolf
# subTable: Flyer Monster: Manticore
# subTable: Giant Monster: Gnoll
# subTable: Undead Monster: Zombie
# subTable: Dragon Monster: Dragon, White
# subTable: Flyer Monster: Griffon
# subTable: Giant Monster: Orc
# subTable: Swimmer Monster: Giant Snake, Constrictor
# subTable: Swimmer Monster: Merman
# subTable: Flyer Monster: Balrog
# subTable: Flyer Monster: Balrog
# subTable: Men Typical Monster: Necromancer
# subTable: Giant Monster: Elf
# subTable: Flyer Monster: Pegasus
# subTable: Lycan Monster: Werebear
# subTable: Giant Monster: Gnoll
# subTable: Lycan Monster: Weretiger
# subTable: Flyer Monster: Griffon
# subTable: Swimmer Monster: Giant Leech
# subTable: Undead Monster: Zombie
# subTable: Dragon Monster: Balrog
# subTable: Undead Monster: Wight
# subTable: Flyer Monster: Wyvern
# subTable: Undead Monster: Vampire
# subTable: Dragon Monster: Wyvern
# subTable: Lycan Monster: Werebear
# subTable: Lycan Monster: Weretiger
# subTable: Flyer Monster: Manticore
# subTable: Undead Monster: Zombie
# subTable: Giant Monster: Troll
# subTable: Men Typical Monster: Wizard
# subTable: Lycan Monster: Weretiger
# subTable: Undead Monster: Wight
# subTable: Undead Monster: Mummy
# subTable: Flyer Monster: Dragon, Gold
# subTable: Swimmer Monster: Merman
# subTable: Lycan Monster: Wereboar
# subTable: Undead Monster: Spectre
# subTable: Flyer Monster: Dragon, Blue
# subTable: Swimmer Monster: Dragon Turtle
# subTable: Undead Monster: Spectre
# subTable: Swimmer Monster: Sea Monster, Small
# subTable: Swimmer Monster: Giant Leech
# subTable: Flyer Monster: Dragon, White
# subTable: Flyer Monster: Manticore
# subTable: Giant Monster: Troll
# subTable: Men Typical Monster: Wizard
# subTable: Undead Monster: Wraith
# subTable: Dragon Monster: Dragon, Black
# subTable: Dragon Monster: Dragon, Red
# subTable: Flyer Monster: Manticore
# subTable: Undead Monster: Ghoul
# subTable: Dragon Monster: Balrog
# subTable: Swimmer Monster: Giant Leech
# subTable: Men Typical Monster: Patriarch
# subTable: Undead Monster: Skeleton
# subTable: Undead Monster: Wraith
# subTable: Men Typical Monster: Bandit
# subTable: Undead Monster: Vampire
# subTable: Dragon Monster: Dragon, White
# subTable: Swimmer Monster: Giant Octopus
# subTable: Lycan Monster: Werewolf
# subTable: Undead Monster: Mummy
# subTable: Flyer Monster: Pegasus
# subTable: Swimmer Monster: Nixie
# subTable: Men Typical Monster: Brigand
# subTable: Lycan Monster: Werewolf
# subTable: Undead Monster: Vampire
# subTable: Undead Monster: Wraith
# subTable: Swimmer Monster: Crocodile
# subTable: Undead Monster: Vampire
# subTable: Swimmer Monster: Giant Squid
# subTable: Flyer Monster: Dragon, Green
# subTable: Dragon Monster: Dragon, Gold
# subTable: Undead Monster: Skeleton
# subTable: Giant Monster: Hobgoblin
# subTable: Swimmer Monster: Giant Fish
# subTable: Giant Monster: Kobold
# subTable: Swimmer Monster: Crocodile
# subTable: Lycan Monster: Werebear
# subTable: Giant Monster: Giant, Stone
# subTable: Lycan Monster: Wereboar
# subTable: Lycan Monster: Werebear
# subTable: Flyer Monster: Wyvern
# subTable: Dragon Monster: Chimera
# subTable: Giant Monster: Dwarf
# subTable: Dragon Monster: Balrog
# subTable: Swimmer Monster: Nixie
# subTable: Flyer Monster: Pegasus
# subTable: Flyer Monster: Pegasus
# subTable: Undead Monster: Vampire
# subTable: Flyer Monster: Pegasus
# subTable: Undead Monster: Vampire
# subTable: Men Typical Monster: Evil High Priest
# subTable: Undead Monster: Spectre
# subTable: Flyer Monster: Griffon
# subTable: Men Typical Monster: Bandit
# subTable: Dragon Monster: Dragon, Gold
# subTable: Giant Monster: Giant, Hill
# subTable: Dragon Monster: Chimera
# subTable: Undead Monster: Spectre
# subTable: Flyer Monster: Balrog
# subTable: Men Typical Monster: Bandit
# subTable: Flyer Monster: Dragon, Black
# subTable: Undead Monster: Mummy
# subTable: Dragon Monster: Dragon, Blue
# subTable: Undead Monster: Ghoul
# subTable: Swimmer Monster: Giant Fish
# subTable: Men Typical Monster: Brigand
# subTable: Men Typical Monster: Wizard
# subTable: Swimmer Monster: Nixie
# subTable: Undead Monster: Vampire
# subTable: Dragon Monster: Wyvern
# subTable: Undead Monster: Wight
# subTable: Swimmer Monster: Merman
# subTable: Flyer Monster: Dragon, Green
# subTable: Undead Monster: Skeleton
# subTable: Men Typical Monster: Brigand
# subTable: Swimmer Monster: Giant Octopus
# subTable: Undead Monster: Vampire
# subTable: Undead Monster: Zombie
# subTable: Lycan Monster: Werebear
# subTable: Undead Monster: Vampire
# subTable: Giant Monster: Ogre
# subTable: Undead Monster: Zombie
# subTable: Dragon Monster: Dragon, Blue
# subTable: Lycan Monster: Werebear
# subTable: Dragon Monster: Balrog
# subTable: Men Typical Monster: Brigand
# subTable: Swimmer Monster: Nixie
# subTable: Flyer Monster: Dragon, White
# subTable: Lycan Monster: Werebear
# subTable: Lycan Monster: Werebear
# subTable: Undead Monster: Wraith
# subTable: Swimmer Monster: Merman
# subTable: Undead Monster: Zombie
# subTable: Undead Monster: Ghoul
# subTable: Flyer Monster: Balrog
# subTable: Swimmer Monster: Giant Squid
# subTable: Men Typical Monster: Brigand
# subTable: Dragon Monster: Hydra, 10 Heads
# subTable: Undead Monster: Wight
# subTable: Lycan Monster: Werewolf
# subTable: Flyer Monster: Chimera
# subTable: Giant Monster: Ogre
# subTable: Men Typical Monster: Evil High Priest
# subTable: Swimmer Monster: Giant Crab
# subTable: Flyer Monster: Griffon
# subTable: Undead Monster: Zombie
# subTable: Dragon Monster: Chimera
# subTable: Swimmer Monster: Nixie
# subTable: Lycan Monster: Wereboar
# subTable: Lycan Monster: Weretiger
# subTable: Lycan Monster: Weretiger
# subTable: Lycan Monster: Wereboar
# subTable: Lycan Monster: Weretiger
# subTable: Swimmer Monster: Dragon Turtle
# subTable: Lycan Monster: Weretiger
# subTable: Men Typical Monster: Brigand
# subTable: Dragon Monster: Dragon, Red
# subTable: Giant Monster: Treant
# subTable: Dragon Monster: Dragon, White
# subTable: Men Typical Monster: Necromancer
# subTable: Undead Monster: Wight
# subTable: Swimmer Monster: Dragon Turtle
# subTable: Undead Monster: Ghoul
# subTable: Men Typical Monster: Necromancer
# subTable: Lycan Monster: Wereboar
# subTable: Giant Monster: Treant
# subTable: Undead Monster: Spectre
# subTable: Lycan Monster: Werebear
# subTable: Giant Monster: Gnoll
# subTable: Swimmer Monster: Merman
# subTable: Lycan Monster: Werebear
# subTable: Undead Monster: Spectre
# subTable: Giant Monster: Gnoll
# subTable: Men Typical Monster: Wizard
# subTable: Dragon Monster: Chimera
# subTable: Lycan Monster: Wereboar
# subTable: Men Typical Monster: Bandit
# subTable: Dragon Monster: Hydra, 10 Heads
# subTable: Dragon Monster: Dragon, White
# subTable: Flyer Monster: Roc, Small
# subTable: Giant Monster: Kobold
# subTable: Giant Monster: Treant
# subTable: Undead Monster: Wraith
# subTable: Dragon Monster: Chimera
# subTable: Swimmer Monster: Nixie
# subTable: Undead Monster: Zombie
# subTable: Dragon Monster: Dragon, Blue
# subTable: Giant Monster: Orc
# subTable: Dragon Monster: Cockatrice
# subTable: Dragon Monster: Cockatrice
# subTable: Undead Monster: Wight
# subTable: Undead Monster: Skeleton
# subTable: Undead Monster: Ghoul
# subTable: Giant Monster: Dwarf
# subTable: Undead Monster: Ghoul
# subTable: Giant Monster: Treant
# subTable: Flyer Monster: Hippogriff
# subTable: Swimmer Monster: Giant Leech
# subTable: Lycan Monster: Weretiger
# subTable: Dragon Monster: Wyvern
# subTable: Swimmer Monster: Giant Leech
# subTable: Lycan Monster: Werewolf
# subTable: Lycan Monster: Werewolf
# subTable: Undead Monster: Wight
# subTable: Swimmer Monster: Giant Octopus
# subTable: Lycan Monster: Werewolf
# subTable: Giant Monster: Goblin
# subTable: Lycan Monster: Werebear
# subTable: Swimmer Monster: Sea Monster, Small
# subTable: Undead Monster: Mummy
# subTable: Flyer Monster: Chimera
# subTable: Undead Monster: Mummy
# subTable: Undead Monster: Mummy
# subTable: Undead Monster: Mummy
# subTable: Undead Monster: Mummy
# subTable: Swimmer Monster: Sea Monster, Small
# subTable: Men Typical Monster: Bandit
# subTable: Lycan Monster: Werewolf
# subTable: Undead Monster: Spectre
# subTable: Dragon Monster: Dragon, Black
# subTable: Swimmer Monster: Giant Snake, Constrictor
# subTable: Giant Monster: Kobold
# subTable: Dragon Monster: Dragon, Blue
# subTable: Swimmer Monster: Sea Monster, Small
# subTable: Men Typical Monster: Berserker
# subTable: Men Typical Monster: Necromancer
# subTable: Swimmer Monster: Giant Leech
# subTable: Undead Monster: Ghoul
# subTable: Dragon Monster: Dragon, Blue
# subTable: Undead Monster: Spectre
# subTable: Swimmer Monster: Giant Squid
# subTable: Undead Monster: Zombie
# subTable: Men Typical Monster: Bandit
# subTable: Dragon Monster: Dragon, White
# subTable: Undead Monster: Spectre
# subTable: Swimmer Monster: Giant Octopus
# subTable: Flyer Monster: Hippogriff
# subTable: Flyer Monster: Wyvern
# subTable: Undead Monster: Ghoul
# subTable: Undead Monster: Wraith
# subTable: Men Typical Monster: Patriarch
# subTable: Undead Monster: Mummy
# subTable: Men Typical Monster: Superhero
# subTable: Men Typical Monster: Patriarch
# subTable: Undead Monster: Spectre
# subTable: Undead Monster: Skeleton
# subTable: Lycan Monster: Weretiger
# subTable: Undead Monster: Zombie
# subTable: Dragon Monster: Dragon, White
# subTable: Men Typical Monster: Brigand
# subTable: Flyer Monster: Dragon, Gold
# subTable: Undead Monster: Wraith
# subTable: Undead Monster: Spectre
# subTable: Undead Monster: Spectre
# subTable: Swimmer Monster: Giant Crab
# subTable: Dragon Monster: Wyvern
# subTable: Men Typical Monster: Superhero
# subTable: Undead Monster: Wight
# subTable: Giant Monster: Ogre
# subTable: Dragon Monster: Basilisk
# subTable: Lycan Monster: Werebear
# subTable: Swimmer Monster: Nixie
# subTable: Undead Monster: Ghoul
# subTable: Giant Monster: Dwarf
# subTable: Undead Monster: Zombie
# subTable: Undead Monster: Wraith
# subTable: Flyer Monster: Hippogriff
# subTable: Giant Monster: Giant, Stone
# subTable: Lycan Monster: Weretiger
# subTable: Giant Monster: Goblin
# subTable: Dragon Monster: Chimera
# subTable: Flyer Monster: Roc, Small
# subTable: Undead Monster: Ghoul
# subTable: Flyer Monster: Pegasus
# subTable: Flyer Monster: Wyvern
# subTable: Dragon Monster: Wyvern
# subTable: Flyer Monster: Chimera
# subTable: Dragon Monster: Cockatrice
# subTable: Flyer Monster: Manticore
# subTable: Undead Monster: Wight
# subTable: Swimmer Monster: Giant Octopus
# subTable: Giant Monster: Goblin
# subTable: Men Typical Monster: Bandit
# subTable: Swimmer Monster: Dragon Turtle
# subTable: Dragon Monster: Balrog
# subTable: Giant Monster: Orc
# subTable: Giant Monster: Gnoll
# subTable: Undead Monster: Zombie
# subTable: Undead Monster: Ghoul
# subTable: Dragon Monster: Basilisk
# subTable: Lycan Monster: Werebear
# subTable: Men Typical Monster: Necromancer
# subTable: Swimmer Monster: Dragon Turtle
# subTable: Lycan Monster: Werewolf
# subTable: Dragon Monster: Wyvern
# subTable: Giant Monster: Orc
# subTable: Dragon Monster: Basilisk
# subTable: Flyer Monster: Chimera
# subTable: Men Typical Monster: Necromancer
# subTable: Undead Monster: Wraith
# subTable: Undead Monster: Wraith
# subTable: Giant Monster: Dwarf
# subTable: Undead Monster: Wraith
# subTable: Lycan Monster: Werewolf
# subTable: Men Typical Monster: Brigand
# subTable: Giant Monster: Gnome
# subTable: Undead Monster: Zombie
# subTable: Men Typical Monster: Bandit
# subTable: Men Typical Monster: Bandit
# subTable: Flyer Monster: Pegasus
# subTable: Undead Monster: Skeleton
# subTable: Undead Monster: Spectre
# subTable: Lycan Monster: Wereboar
# subTable: Undead Monster: Wraith
# subTable: Undead Monster: Ghoul
# subTable: Flyer Monster: Hippogriff
# subTable: Swimmer Monster: Giant Squid
# subTable: Undead Monster: Spectre
# subTable: Dragon Monster: Dragon, Gold
# subTable: Undead Monster: Vampire
# subTable: Swimmer Monster: Giant Fish
# subTable: Flyer Monster: Pegasus
# subTable: Men Typical Monster: Patriarch
# subTable: Undead Monster: Ghoul
# subTable: Men Typical Monster: Bandit
# subTable: Undead Monster: Wraith
# subTable: Lycan Monster: Werewolf
# subTable: Undead Monster: Spectre
# subTable: Men Typical Monster: Berserker
# subTable: Giant Monster: Gnome
# subTable: Undead Monster: Spectre
# subTable: Lycan Monster: Weretiger
# subTable: Dragon Monster: Chimera
# subTable: Undead Monster: Wraith
# subTable: Flyer Monster: Hippogriff
# subTable: Men Typical Monster: Berserker
# subTable: Swimmer Monster: Giant Crab
# subTable: Flyer Monster: Hippogriff
# subTable: Flyer Monster: Dragon, Black
# subTable: Swimmer Monster: Giant Squid
# subTable: Swimmer Monster: Giant Squid
# subTable: Giant Monster: Giant, Hill
# subTable: Undead Monster: Wight
# subTable: Undead Monster: Wraith
# subTable: Undead Monster: Mummy
# subTable: Men Typical Monster: Superhero
# subTable: Men Typical Monster: Bandit
# subTable: Dragon Monster: Balrog
# subTable: Swimmer Monster: Giant Fish
# subTable: Lycan Monster: Werebear
# subTable: Undead Monster: Spectre
# subTable: Swimmer Monster: Nixie
# subTable: Swimmer Monster: Nixie
# subTable: Swimmer Monster: Giant Squid
# subTable: Giant Monster: Gnoll
# subTable: Swimmer Monster: Crocodile
# subTable: Dragon Monster: Dragon, Gold
# subTable: Flyer Monster: Wyvern
# subTable: Swimmer Monster: Giant Squid
# subTable: Swimmer Monster: Nixie
# subTable: Undead Monster: Wraith
# subTable: Flyer Monster: Griffon
# subTable: Dragon Monster: Balrog
# subTable: Men Typical Monster: Necromancer
# subTable: Giant Monster: Elf
# subTable: Swimmer Monster: Giant Snake, Constrictor
# subTable: Giant Monster: Treant
# subTable: Swimmer Monster: Giant Crab
# subTable: Dragon Monster: Hydra, 10 Heads
# subTable: Undead Monster: Wraith
# subTable: Men Typical Monster: Brigand
# subTable: Undead Monster: Spectre
# subTable: Undead Monster: Wraith
# subTable: Men Typical Monster: Evil High Priest
# subTable: Lycan Monster: Werewolf
# subTable: Lycan Monster: Weretiger
# subTable: Dragon Monster: Dragon, Gold
# subTable: Undead Monster: Ghoul
# subTable: Lycan Monster: Werewolf
# subTable: Flyer Monster: Griffon
# subTable: Undead Monster: Zombie
# subTable: Undead Monster: Vampire
# subTable: Lycan Monster: Wereboar
# subTable: Dragon Monster: Hydra, 10 Heads
# subTable: Dragon Monster: Wyvern
# subTable: Dragon Monster: Dragon, Green
# subTable: Undead Monster: Wraith
# subTable: Swimmer Monster: Sea Monster, Small
# subTable: Swimmer Monster: Merman
# subTable: Flyer Monster: Pegasus
# subTable: Giant Monster: Kobold
# subTable: Dragon Monster: Cockatrice
# subTable: Undead Monster: Vampire
# subTable: Undead Monster: Wraith
# subTable: Undead Monster: Mummy
# subTable: Undead Monster: Wight
# subTable: Lycan Monster: Werebear
# subTable: Undead Monster: Spectre
# subTable: Undead Monster: Mummy
# subTable: Flyer Monster: Wyvern
# subTable: Men Typical Monster: Brigand
# subTable: Dragon Monster: Dragon, Blue
# subTable: Lycan Monster: Weretiger
# subTable: Flyer Monster: Manticore
# subTable: Flyer Monster: Chimera
# subTable: Swimmer Monster: Sea Monster, Small
# subTable: Giant Monster: Elf
# subTable: Swimmer Monster: Giant Squid
# subTable: Men Typical Monster: Wizard
# subTable: Flyer Monster: Roc, Small
# subTable: Men Typical Monster: Superhero
# subTable: Lycan Monster: Werewolf
# subTable: Undead Monster: Ghoul
# subTable: Giant Monster: Giant, Hill
# subTable: Lycan Monster: Wereboar
# subTable: Undead Monster: Ghoul
# subTable: Swimmer Monster: Giant Snake, Constrictor
# subTable: Undead Monster: Ghoul
# subTable: Swimmer Monster: Nixie
# subTable: Undead Monster: Spectre
# subTable: Undead Monster: Spectre
# subTable: Giant Monster: Elf
# subTable: Swimmer Monster: Giant Leech
# subTable: Undead Monster: Mummy
# subTable: Flyer Monster: Hippogriff
# subTable: Flyer Monster: Hippogriff
# subTable: Lycan Monster: Werebear
# subTable: Men Typical Monster: Brigand
# subTable: Giant Monster: Hobgoblin
# subTable: Dragon Monster: Basilisk
# subTable: Flyer Monster: Pegasus
# subTable: Giant Monster: Gnoll
# subTable: Undead Monster: Wraith
# subTable: Undead Monster: Spectre
# subTable: Undead Monster: Ghoul
# subTable: Dragon Monster: Cockatrice
# subTable: Dragon Monster: Dragon, Red
# subTable: Undead Monster: Wight
# subTable: Men Typical Monster: Bandit
# subTable: Swimmer Monster: Giant Leech
# subTable: Giant Monster: Goblin
# subTable: Swimmer Monster: Giant Leech
# subTable: Men Typical Monster: Necromancer
# subTable: Swimmer Monster: Dragon Turtle
# subTable: Dragon Monster: Wyvern
# subTable: Flyer Monster: Hippogriff
# subTable: Giant Monster: Hobgoblin
# subTable: Undead Monster: Wight
# subTable: Giant Monster: Gnoll
# subTable: Giant Monster: Troll
# subTable: Men Typical Monster: Bandit
# subTable: Lycan Monster: Werebear
# subTable: Flyer Monster: Pegasus
# subTable: Dragon Monster: Chimera
# subTable: Undead Monster: Wight
# subTable: Giant Monster: Dwarf
# subTable: Giant Monster: Hobgoblin
# subTable: Lycan Monster: Werebear
# subTable: Giant Monster: Dwarf
# subTable: Undead Monster: Vampire
# subTable: Swimmer Monster: Nixie
# subTable: Men Typical Monster: Wizard
# subTable: Dragon Monster: Dragon, Gold
# subTable: Flyer Monster: Pegasus
# subTable: Giant Monster: Gnoll
# subTable: Giant Monster: Ogre
# subTable: Undead Monster: Ghoul
# subTable: Lycan Monster: Werebear
# subTable: Undead Monster: Skeleton
# subTable: Flyer Monster: Balrog
# subTable: Undead Monster: Spectre
# subTable: Giant Monster: Treant
# subTable: Men Typical Monster: Bandit
# subTable: Flyer Monster: Balrog
# subTable: Undead Monster: Spectre
# subTable: Swimmer Monster: Dragon Turtle
# subTable: Lycan Monster: Weretiger
# subTable: Lycan Monster: Weretiger
# subTable: Giant Monster: Treant
# subTable: Swimmer Monster: Merman
# subTable: Giant Monster: Dwarf
# subTable: Men Typical Monster: Brigand
# subTable: Lycan Monster: Werewolf
# subTable: Dragon Monster: Hydra, 10 Heads
# subTable: Swimmer Monster: Nixie
# subTable: Flyer Monster: Dragon, Blue
# subTable: Flyer Monster: Chimera
# subTable: Flyer Monster: Dragon, Red
# subTable: Men Typical Monster: Bandit
# subTable: Undead Monster: Wraith
# subTable: Flyer Monster: Manticore
# subTable: Undead Monster: Vampire
# subTable: Dragon Monster: Dragon, White
# subTable: Undead Monster: Skeleton
# subTable: Undead Monster: Zombie
# subTable: Undead Monster: Mummy
# subTable: Men Typical Monster: Brigand
# subTable: Lycan Monster: Werewolf
# subTable: Men Typical Monster: Bandit
# subTable: Flyer Monster: Manticore
# subTable: Giant Monster: Giant, Stone
# subTable: Lycan Monster: Werewolf
# subTable: Men Typical Monster: Bandit
# subTable: Giant Monster: Treant
# subTable: Giant Monster: Ogre
# subTable: Flyer Monster: Hippogriff
# subTable: Flyer Monster: Balrog
# subTable: Lycan Monster: Werewolf
# subTable: Flyer Monster: Chimera
# subTable: Swimmer Monster: Giant Leech
# subTable: Giant Monster: Gnome
# subTable: Swimmer Monster: Crocodile
# subTable: Lycan Monster: Weretiger
# subTable: Flyer Monster: Pegasus
# subTable: Swimmer Monster: Giant Crab
# subTable: Flyer Monster: Hippogriff
# subTable: Swimmer Monster: Crocodile
# subTable: Undead Monster: Spectre
# subTable: Lycan Monster: Wereboar
# subTable: Swimmer Monster: Dragon Turtle
# subTable: Undead Monster: Spectre
# subTable: Undead Monster: Skeleton
# subTable: Giant Monster: Ogre
# subTable: Undead Monster: Ghoul
# subTable: Flyer Monster: Dragon, Black
# subTable: Giant Monster: Orc
# subTable: Lycan Monster: Wereboar
# subTable: Lycan Monster: Weretiger
# subTable: Lycan Monster: Wereboar
# subTable: Lycan Monster: Weretiger
# subTable: Flyer Monster: Wyvern
# subTable: Lycan Monster: Werebear
# subTable: Flyer Monster: Hippogriff
# subTable: Swimmer Monster: Giant Squid
# subTable: Undead Monster: Wight
# subTable: Lycan Monster: Werewolf
# subTable: Swimmer Monster: Nixie
# subTable: Lycan Monster: Wereboar
# subTable: Undead Monster: Vampire
# subTable: Giant Monster: Ogre
# subTable: Giant Monster: Dwarf
# subTable: Flyer Monster: Roc, Small
# subTable: Giant Monster: Giant, Hill
# subTable: Men Typical Monster: Lord
# subTable: Giant Monster: Hobgoblin
# subTable: Undead Monster: Vampire
# subTable: Flyer Monster: Wyvern
# subTable: Swimmer Monster: Crocodile
# subTable: Swimmer Monster: Dragon Turtle
# subTable: Flyer Monster: Wyvern
# subTable: Giant Monster: Ogre
# subTable: Flyer Monster: Pegasus
# subTable: Undead Monster: Mummy
# subTable: Swimmer Monster: Giant Octopus
# subTable: Swimmer Monster: Giant Octopus
# subTable: Swimmer Monster: Merman
# subTable: Flyer Monster: Wyvern
# subTable: Undead Monster: Vampire
# subTable: Undead Monster: Spectre
# subTable: Giant Monster: Gnome
# subTable: Lycan Monster: Weretiger
# subTable: Lycan Monster: Werewolf
# subTable: Undead Monster: Wraith
# subTable: Undead Monster: Zombie
# subTable: Swimmer Monster: Crocodile
# subTable: Lycan Monster: Werewolf
# subTable: Flyer Monster: Hippogriff
# subTable: Giant Monster: Hobgoblin
# subTable: Undead Monster: Ghoul
# subTable: Lycan Monster: Wereboar
# subTable: Swimmer Monster: Giant Leech
# subTable: Lycan Monster: Werebear
# subTable: Men Typical Monster: Evil High Priest
# subTable: Dragon Monster: Dragon, Green
# subTable: Men Typical Monster: Brigand
# subTable: Swimmer Monster: Dragon Turtle
# subTable: Swimmer Monster: Giant Octopus
# subTable: Swimmer Monster: Giant Fish
# subTable: Men Typical Monster: Berserker
# subTable: Undead Monster: Spectre
# subTable: Flyer Monster: Manticore
# subTable: Lycan Monster: Werewolf
# subTable: Dragon Monster: Basilisk
# subTable: Flyer Monster: Griffon
# subTable: Undead Monster: Vampire
# subTable: Lycan Monster: Werewolf
# subTable: Lycan Monster: Wereboar
# subTable: Giant Monster: Kobold
# subTable: Flyer Monster: Wyvern
# subTable: Undead Monster: Mummy
# subTable: Giant Monster: Kobold
# subTable: Men Typical Monster: Wizard
# subTable: Men Typical Monster: Patriarch
# subTable: Lycan Monster: Werebear
# subTable: Flyer Monster: Pegasus
# subTable: Dragon Monster: Dragon, Green
# subTable: Undead Monster: Zombie
# subTable: Lycan Monster: Werebear
# subTable: Undead Monster: Spectre
# subTable: Men Typical Monster: Lord
# subTable: Flyer Monster: Hippogriff
# subTable: Flyer Monster: Roc, Small
# subTable: Swimmer Monster: Giant Fish
# subTable: Giant Monster: Treant
# subTable: Giant Monster: Treant
# subTable: Swimmer Monster: Nixie
# subTable: Flyer Monster: Wyvern
# subTable: Men Typical Monster: Wizard
# subTable: Dragon Monster: Balrog
# subTable: Flyer Monster: Hippogriff
# subTable: Undead Monster: Skeleton
# subTable: Giant Monster: Gnoll
# subTable: Dragon Monster: Cockatrice
# subTable: Flyer Monster: Pegasus
# subTable: Undead Monster: Mummy
# subTable: Giant Monster: Elf
# subTable: Undead Monster: Skeleton
# subTable: Swimmer Monster: Nixie
# subTable: Men Typical Monster: Lord
# subTable: Undead Monster: Spectre
# subTable: Undead Monster: Mummy
# subTable: Men Typical Monster: Wizard
# subTable: Flyer Monster: Hippogriff
# subTable: Flyer Monster: Hippogriff
# subTable: Undead Monster: Spectre
# subTable: Undead Monster: Spectre
# subTable: Men Typical Monster: Bandit
# subTable: Swimmer Monster: Giant Crab
# subTable: Undead Monster: Zombie
# subTable: Undead Monster: Ghoul
# subTable: Giant Monster: Goblin
# subTable: Giant Monster: Gnome
# subTable: Undead Monster: Ghoul
# subTable: Lycan Monster: Wereboar
# subTable: Undead Monster: Ghoul
# subTable: Undead Monster: Wight
# subTable: Undead Monster: Mummy
# subTable: Dragon Monster: Dragon, Green
# subTable: Flyer Monster: Pegasus
# subTable: Swimmer Monster: Giant Octopus
# subTable: Undead Monster: Skeleton
# subTable: Lycan Monster: Weretiger
# subTable: Flyer Monster: Hippogriff
# subTable: Dragon Monster: Balrog
# subTable: Men Typical Monster: Brigand
# subTable: Undead Monster: Ghoul
# subTable: Undead Monster: Mummy
# subTable: Lycan Monster: Wereboar
# subTable: Men Typical Monster: Patriarch
# subTable: Dragon Monster: Dragon, White
# subTable: Dragon Monster: Dragon, Blue
# subTable: Giant Monster: Elf
# subTable: Dragon Monster: Balrog
# subTable: Swimmer Monster: Nixie
# subTable: Giant Monster: Giant, Cloud
# subTable: Lycan Monster: Weretiger
# subTable: Lycan Monster: Weretiger
# subTable: Men Typical Monster: Superhero
# subTable: Undead Monster: Spectre
# subTable: Undead Monster: Mummy
# subTable: Lycan Monster: Weretiger
# subTable: Undead Monster: Ghoul
# subTable: Undead Monster: Zombie
# subTable: Swimmer Monster: Merman
# subTable: Flyer Monster: Roc, Small
# subTable: Flyer Monster: Hippogriff
# subTable: Undead Monster: Vampire
# subTable: Lycan Monster: Wereboar
# subTable: Swimmer Monster: Dragon Turtle
# subTable: Undead Monster: Ghoul
# subTable: Giant Monster: Troll
# subTable: Lycan Monster: Wereboar
# subTable: Undead Monster: Skeleton
# subTable: Flyer Monster: Balrog
# subTable: Swimmer Monster: Giant Squid
# subTable: Dragon Monster: Cockatrice
# subTable: Flyer Monster: Wyvern
# subTable: Swimmer Monster: Giant Leech
# subTable: Men Typical Monster: Wizard
# subTable: Dragon Monster: Dragon, White
# subTable: Dragon Monster: Hydra, 10 Heads
# subTable: Flyer Monster: Pegasus
# subTable: Men Typical Monster: Bandit
# subTable: Undead Monster: Mummy
# subTable: Flyer Monster: Hippogriff
# subTable: Undead Monster: Zombie
# subTable: Flyer Monster: Hippogriff
# subTable: Giant Monster: Gnome
# subTable: Undead Monster: Wraith
# subTable: Undead Monster: Zombie
# subTable: Giant Monster: Elf
# subTable: Men Typical Monster: Necromancer
# subTable: Lycan Monster: Werewolf
# subTable: Flyer Monster: Chimera
# subTable: Dragon Monster: Dragon, Gold
# subTable: Undead Monster: Mummy
# subTable: Flyer Monster: Dragon, Blue
# subTable: Men Typical Monster: Bandit
# subTable: Men Typical Monster: Bandit
# subTable: Undead Monster: Spectre
# subTable: Giant Monster: Elf
# subTable: Giant Monster: Goblin
# subTable: Giant Monster: Elf
# subTable: Flyer Monster: Balrog
# subTable: Lycan Monster: Wereboar
# subTable: Men Typical Monster: Brigand
# subTable: Giant Monster: Giant, Hill
# subTable: Flyer Monster: Hippogriff
# subTable: Flyer Monster: Pegasus
# subTable: Undead Monster: Ghoul
# subTable: Dragon Monster: Chimera
# subTable: Flyer Monster: Pegasus
# subTable: Dragon Monster: Dragon, Blue
# subTable: Undead Monster: Vampire
# subTable: Flyer Monster: Griffon
# subTable: Swimmer Monster: Giant Fish
# subTable: Lycan Monster: Weretiger
# subTable: Undead Monster: Wight
# subTable: Undead Monster: Spectre
# subTable: Lycan Monster: Werebear
# subTable: Flyer Monster: Dragon, White
# subTable: Men Typical Monster: Bandit
# subTable: Dragon Monster: Dragon, Blue
# subTable: Undead Monster: Vampire
# subTable: Dragon Monster: Dragon, Red
# subTable: Undead Monster: Ghoul
# subTable: Dragon Monster: Dragon, Gold
# subTable: Swimmer Monster: Crocodile
# subTable: Undead Monster: Wight
# subTable: Undead Monster: Wraith
# subTable: Undead Monster: Ghoul
# subTable: Men Typical Monster: Bandit
# subTable: Dragon Monster: Chimera
# subTable: Swimmer Monster: Giant Leech
# subTable: Dragon Monster: Dragon, Gold
# subTable: Dragon Monster: Dragon, White
# subTable: Lycan Monster: Weretiger
# subTable: Swimmer Monster: Giant Fish
# subTable: Flyer Monster: Griffon
# subTable: Giant Monster: Goblin
# subTable: Swimmer Monster: Nixie
# subTable: Giant Monster: Troll
# subTable: Lycan Monster: Werebear
# subTable: Undead Monster: Zombie
# subTable: Undead Monster: Zombie
# subTable: Dragon Monster: Balrog
# subTable: Men Typical Monster: Patriarch
# subTable: Dragon Monster: Dragon, Green
# subTable: Swimmer Monster: Giant Octopus
# subTable: Swimmer Monster: Giant Snake, Constrictor
# subTable: Men Typical Monster: Bandit
# subTable: Lycan Monster: Weretiger
# subTable: Undead Monster: Skeleton
# subTable: Dragon Monster: Balrog
# subTable: Dragon Monster: Dragon, Black
# subTable: Lycan Monster: Wereboar
# subTable: Undead Monster: Zombie
# subTable: Men Typical Monster: Brigand
# subTable: Undead Monster: Spectre
# subTable: Undead Monster: Skeleton
# subTable: Flyer Monster: Griffon
# subTable: Flyer Monster: Dragon, Green
# subTable: Swimmer Monster: Giant Leech
# subTable: Swimmer Monster: Giant Snake, Constrictor
# subTable: Swimmer Monster: Giant Fish
# subTable: Men Typical Monster: Necromancer
# subTable: Men Typical Monster: Berserker
# subTable: Lycan Monster: Wereboar
# subTable: Swimmer Monster: Nixie
# subTable: Undead Monster: Wight
# subTable: Undead Monster: Ghoul
# subTable: Undead Monster: Skeleton
# subTable: Undead Monster: Spectre
# subTable: Men Typical Monster: Superhero
# subTable: Dragon Monster: Balrog
# subTable: Undead Monster: Zombie
# subTable: Dragon Monster: Basilisk
# subTable: Swimmer Monster: Giant Octopus
# subTable: Flyer Monster: Pegasus
# subTable: Flyer Monster: Manticore
# subTable: Giant Monster: Ogre
# subTable: Giant Monster: Gnome
# subTable: Giant Monster: Goblin
# subTable: Dragon Monster: Basilisk
# subTable: Dragon Monster: Chimera
# subTable: Undead Monster: Ghoul
# subTable: Undead Monster: Zombie
# subTable: Giant Monster: Elf
# subTable: Swimmer Monster: Crocodile
# subTable: Swimmer Monster: Giant Crab
# subTable: Swimmer Monster: Giant Leech
# subTable: Giant Monster: Elf
# subTable: Lycan Monster: Wereboar
# subTable: Flyer Monster: Hippogriff
# subTable: Swimmer Monster: Giant Squid
# subTable: Flyer Monster: Manticore
# subTable: Undead Monster: Spectre
# subTable: Swimmer Monster: Nixie
# subTable: Flyer Monster: Balrog
# subTable: Swimmer Monster: Giant Fish
# subTable: Flyer Monster: Hippogriff
# subTable: Dragon Monster: Cockatrice
# subTable: Men Typical Monster: Patriarch
# subTable: Undead Monster: Wight
# subTable: Swimmer Monster: Giant Crab
# subTable: Undead Monster: Mummy
# subTable: Men Typical Monster: Bandit
# subTable: Men Typical Monster: Brigand
# subTable: Lycan Monster: Werewolf
# subTable: Lycan Monster: Weretiger
# subTable: Undead Monster: Wight
# subTable: Flyer Monster: Wyvern
# subTable: Flyer Monster: Chimera
# subTable: Undead Monster: Wraith
# subTable: Undead Monster: Ghoul
# subTable: Swimmer Monster: Giant Octopus
# subTable: Lycan Monster: Werebear
# subTable: Flyer Monster: Pegasus
# subTable: Flyer Monster: Pegasus
# subTable: Swimmer Monster: Giant Fish
# subTable: Dragon Monster: Cockatrice
# subTable: Giant Monster: Ogre
# subTable: Swimmer Monster: Nixie
# subTable: Flyer Monster: Balrog
# subTable: Swimmer Monster: Giant Fish
# subTable: Dragon Monster: Chimera
# subTable: Swimmer Monster: Giant Octopus
# subTable: Lycan Monster: Werewolf
# subTable: Dragon Monster: Dragon, Green
# subTable: Lycan Monster: Weretiger
# subTable: Swimmer Monster: Giant Fish
# subTable: Men Typical Monster: Necromancer
# subTable: Undead Monster: Wraith
# subTable: Men Typical Monster: Wizard
# subTable: Swimmer Monster: Giant Leech
# subTable: Flyer Monster: Hippogriff
# subTable: Undead Monster: Skeleton
# subTable: Giant Monster: Gnome
# subTable: Men Typical Monster: Brigand
# subTable: Flyer Monster: Pegasus
# subTable: Undead Monster: Vampire
# subTable: Undead Monster: Skeleton
# subTable: Undead Monster: Zombie
# subTable: Swimmer Monster: Giant Fish
# subTable: Flyer Monster: Wyvern
# subTable: Swimmer Monster: Merman
# subTable: Dragon Monster: Balrog
# subTable: Swimmer Monster: Giant Octopus
# subTable: Lycan Monster: Weretiger
# subTable: Swimmer Monster: Giant Snake, Constrictor
# subTable: Undead Monster: Ghoul
# subTable: Swimmer Monster: Giant Leech
# subTable: Men Typical Monster: Superhero
# subTable: Giant Monster: Kobold
# subTable: Dragon Monster: Wyvern
# subTable: Giant Monster: Gnoll
# subTable: Giant Monster: Troll
# subTable: Flyer Monster: Hippogriff
# subTable: Men Typical Monster: Evil High Priest
# subTable: Lycan Monster: Weretiger
# subTable: Lycan Monster: Werebear
# subTable: Undead Monster: Vampire
# subTable: Flyer Monster: Roc, Small
# subTable: Dragon Monster: Dragon, Blue
# subTable: Swimmer Monster: Nixie
# subTable: Lycan Monster: Weretiger
# subTable: Undead Monster: Wight
# subTable: Dragon Monster: Balrog
# subTable: Men Typical Monster: Superhero
# subTable: Men Typical Monster: Wizard
# subTable: Flyer Monster: Hippogriff
# subTable: Undead Monster: Spectre
# subTable: Flyer Monster: Chimera
# subTable: Flyer Monster: Chimera
# subTable: Undead Monster: Wraith
# subTable: Dragon Monster: Balrog
# subTable: Giant Monster: Orc
# subTable: Dragon Monster: Balrog
# subTable: Giant Monster: Giant, Hill
# subTable: Flyer Monster: Roc, Small
# subTable: Dragon Monster: Dragon, Gold
# subTable: Dragon Monster: Balrog
# subTable: Undead Monster: Wight
# subTable: Lycan Monster: Werebear
# subTable: Flyer Monster: Pegasus
# subTable: Dragon Monster: Dragon, Gold
# subTable: Lycan Monster: Weretiger
# subTable: Giant Monster: Treant
# subTable: Undead Monster: Zombie
# subTable: Undead Monster: Skeleton
# subTable: Flyer Monster: Roc, Small
# subTable: Dragon Monster: Dragon, Gold
# subTable: Undead Monster: Wight
# subTable: Swimmer Monster: Merman
# subTable: Giant Monster: Treant
# subTable: Lycan Monster: Weretiger
# subTable: Undead Monster: Mummy
# subTable: Lycan Monster: Wereboar
# subTable: Lycan Monster: Wereboar
# subTable: Men Typical Monster: Lord
# subTable: Swimmer Monster: Giant Octopus
# subTable: Undead Monster: Mummy
# subTable: Undead Monster: Mummy
# subTable: Lycan Monster: Weretiger
# subTable: Men Typical Monster: Bandit
# subTable: Flyer Monster: Hippogriff
# subTable: Giant Monster: Giant, Hill
# subTable: Men Typical Monster: Bandit
# subTable: Dragon Monster: Balrog
# subTable: Men Typical Monster: Lord
# subTable: Undead Monster: Vampire
# subTable: Dragon Monster: Dragon, Red
# subTable: Giant Monster: Giant, Frost
# subTable: Swimmer Monster: Nixie
# subTable: Giant Monster: Dwarf
# subTable: Flyer Monster: Wyvern
# subTable: Giant Monster: Goblin
# subTable: Giant Monster: Hobgoblin
# subTable: Giant Monster: Treant
# subTable: Swimmer Monster: Crocodile
# subTable: Undead Monster: Skeleton
# subTable: Lycan Monster: Werewolf
# subTable: Lycan Monster: Werewolf

# %%
dfEHD = pd.DataFrame()
dfEHD['subTable'] = encounter_dict['subTable']
dfEHD['Monster'] = encounter_dict['Monster']
dfEHD['EHD'] = encounter_dict['EHD']
dfEHD
# Out:
#     subTable    Monster   EHD
# 0      Flyer     Wyvern   9.0
# 1    Swimmer     Merman  50.0
# 2     Undead     Wraith  40.0
# 3      Lycan   Werewolf  27.0
# 4      Lycan   Werewolf  45.0
# ..       ...        ...   ...
# 995    Giant     Treant  66.0
# 996  Swimmer  Crocodile  28.0
# 997   Undead   Skeleton   4.0
# 998    Lycan   Werewolf  42.0
# 999    Lycan   Werewolf  30.0
#
# [1000 rows x 3 columns]

# %%
dfEHD['EHD'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
